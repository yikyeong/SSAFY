# %%
import os
import sys
import urllib.request

client_id = "zuupf4b56FrdfO8TVHfO"  # 애플리케이션 클라이언트 아이디값
# client_secret = import.meta.env.VITE_NAVER_CLIENT_API_KEY  # 애플리케이션 클라이언트 시크릿값
client_secret = "sulBZ4u2ZD"

query='주가'
encText = urllib.parse.quote(query)
url = "https://openapi.naver.com/v1/search/news?query=" + encText 
# JSON 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Wed, 22 Nov 2023 17:09:00 +0900",
# 	"total":6539816,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"[종합<b>주가<\/b>지수] 코스피, 숨 고르기…<b>주가<\/b>는 LG에너지솔루션↓ 네이버↑",
# 			"originallink":"https:\/\/www.ekn.kr\/web\/view.php?key=20231122010006684",
# 			"link":"https:\/\/www.ekn.kr\/web\/view.php?key=20231122010006684",
# 			"description":"22일 코스피가 전장보다 1.28p(0.05%) 오른 2511.70으로 집계됐다. 지수는 전장보다 17.25p(0.69%) 내린 2493.17에 개장한 뒤 지지부진하다 상승 전환했다. 유가증권시장에서 외국인은 1431억원어치를 순매수했다. 반면... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:08:00 +0900"
# 		},
# 		{
# 			"title":"檢, 카카오 판교 사무실 압수수색... 'SM엔터 시세조종 혐의'",
# 			"originallink":"https:\/\/biz.newdaily.co.kr\/site\/data\/html\/2023\/11\/22\/2023112200300.html",
# 			"link":"https:\/\/biz.newdaily.co.kr\/site\/data\/html\/2023\/11\/22\/2023112200300.html",
# 			"description":"뉴데일리 신희강 기자 = 검찰이 카카오의 SM엔터테인먼트 <b>주가<\/b>조작 의혹과 관련해 판교아지트에 대한... 앞서 금융감독원 자본시장특별사법경찰(특사경)은 카카오가 지난 2월 SM엔터 경영권 인수전 당시 SM엔터 <b>주가<\/b>를... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:08:00 +0900"
# 		},
# 		{
# 			"title":"[급등주] 네오리진, <b>주가<\/b> +30% 상한가 마감",
# 			"originallink":"https:\/\/www.jeonmae.co.kr\/news\/articleView.html?idxno=995810",
# 			"link":"https:\/\/www.jeonmae.co.kr\/news\/articleView.html?idxno=995810",
# 			"description":"네오리진 <b>주가<\/b>가 22일 상한가로 거래 마감했다. 이날 네오리진은 전 거래일 대비 30% 상승한 377원에 거래를 마감했다. 거래량은 1682만3,055주다. [전국매일신문] 제갈은기자",
# 			"pubDate":"Wed, 22 Nov 2023 17:06:00 +0900"
# 		},
# 		{
# 			"title":"공매도 금지 2주… 개미는 사고 외국인은 팔고 ‘이차전지 힘겨루기’",
# 			"originallink":"https:\/\/biz.chosun.com\/stock\/market_trend\/2023\/11\/22\/JI2JKFHSMBGA3D5U2HKLN3DYFA\/?utm_source=naver&utm_medium=original&utm_campaign=biz",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/366\/0000949514?sid=101",
# 			"description":"금융당국의 공매도(空賣渡·<b>주가<\/b> 하락을 예상하고 남의 주식을 빌려서 판 뒤 나중에 되갚아 차익을 남기는 투자 기법) 금지 조치 이후 2<b>주가<\/b> 지난 가운데, 개미와 외국인이 이차전지주를 두고 엇갈린 투자 행보로... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:05:00 +0900"
# 		},
# 		{
# 			"title":"모바일 '패스' 앱으로 성인 여부 바로 확인",
# 			"originallink":"https:\/\/www.mk.co.kr\/article\/10881316",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/009\/0005219099?sid=105",
# 			"description":"영업점<b>주가<\/b> 별도의 추가 장비 없이도 패스(PASS) 앱을 이용해 방문 고객이 성인인지를 손쉽게 확인할 수 있게 됐다. SK텔레콤, KT, LG유플러스는 실물 신분증과 동일한 법적 효력을 인정받은 패스 모바일신분증의 QR코드... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:05:00 +0900"
# 		},
# 		{
# 			"title":"&quot;내년 또 경기 불황...중소형 화장품株 강세 이어간다&quot; [투자360]",
# 			"originallink":"http:\/\/news.heraldcorp.com\/view.php?ud=20231122000703",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/016\/0002228535?sid=101",
# 			"description":"내년에도 시장 경기 불확실성이 커지면서 중소형 화장품<b>주가<\/b> 강세를 이어간다는 분석이 나왔다. 중국 시장... 중소형 화장품<b>주가<\/b> 내년에도 성장세를 이어갈 가능성이 크다. 하 연구원은 &quot;최근 한국의 화장품 수출 국가별... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:05:00 +0900"
# 		},
# 		{
# 			"title":"증권사, 도 넘은 극성 투자자 집단행동에 골머리",
# 			"originallink":"http:\/\/www.goodkyung.com\/news\/articleView.html?idxno=222285",
# 			"link":"http:\/\/www.goodkyung.com\/news\/articleView.html?idxno=222285",
# 			"description":"이들은 연구원의 에코프로 매도 보고서로 인해 <b>주가<\/b>가 하락했으며 투자자들이 큰 손실을 봤다고 주장했다. 연구원은 지난 8일 에코프로 <b>주가<\/b>가 과열돼 있다고 진단한 뒤 목표가를 기존 55만5000원에서 42만원으로 하향... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:04:00 +0900"
# 		},
# 		{
# 			"title":"에코프로머티 코스피200 편입되나?…증권가 &quot;확신 어려워&quot;",
# 			"originallink":"http:\/\/news.mt.co.kr\/mtview.php?no=2023112215163956123",
# 			"link":"https:\/\/n.news.naver.com\/mnews\/article\/008\/0004965032?sid=101",
# 			"description":"에코프로머티리얼즈는 상장 후 3거래일 만에 <b>주가<\/b>가 2배 가까이 올랐다. 상장 당시 3조9026억원이었던... 코스피200에 편입되면 패시브 자금이 유입되는 만큼 추가적인 <b>주가<\/b> 상승을 꾀할 수 있다. 공매도도 전격... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:03:00 +0900"
# 		},
# 		{
# 			"title":"국회 법사위, 국민의힘 '퇴장' vs 민주당 '반발'",
# 			"originallink":"http:\/\/www.metroseoul.co.kr\/article\/20231122500669",
# 			"link":"http:\/\/www.metroseoul.co.kr\/article\/20231122500669",
# 			"description":"반면 홍익표 민주당 원내대표는 BBS라디오에서 '쌍특검법 처리'와 관련해 &quot;아직 확정되진 않았다&quot;면서도 &quot;도이치모터스 <b>주가<\/b> 조작 특검과 대장동 특검 2개는 이번 정기국회 내에서는 반드시 처리해야 된다 이런 기본 입장을... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:02:00 +0900"
# 		},
# 		{
# 			"title":"&quot;E1, 연말배당만 현재<b>주가<\/b> 대비 배당수익률 8.5% 예상&quot;",
# 			"originallink":"http:\/\/www.insightkorea.co.kr\/news\/articleView.html?idxno=123351",
# 			"link":"http:\/\/www.insightkorea.co.kr\/news\/articleView.html?idxno=123351",
# 			"description":"이어 &quot;즉, 중간배당(주당 배당금 700원)을 제외한 연말배당 예상액만 5000원으로서 현재<b>주가<\/b> 대비 배당수익률은 8.5%에 달할 것으로 예상한다&quot;며 &quot;그리고, E1 순이익은 내년에는 전년댑 숨을 고른 후 2025년부터 다시 상승... ",
# 			"pubDate":"Wed, 22 Nov 2023 17:02:00 +0900"
# 		}
# 	]
# }
